# %% [markdown]
# <a href="https://colab.research.google.com/github/kasidejcha/jobsdb_data_scrape/blob/main/run_data_scrape_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/kasidejcha/jobsdb_data_scrape.git scrape
# Out:
# Cloning into 'scrape'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 21 (delta 6), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (21/21), done.

# %%
from scrape import jobsdb_data_scrape

jobsdb_data_scrape.run_jobsdb_scape()
# Out:
# Scrape Page Number(1-3): 1
# Filter unwanted position: Senior
# Filtering out: ['Senior']
#
# Company Name: True Digital Group Co., Ltd.
# Position: Junior Data Scientist
# Location: Huaykwang
# Requirement:
# •  Transform raw data to actionable business insights
# •  Select, configure & implement analytics solutions
# •  Develop job ETL
# Link:  https://th.jobsdb.com/th/en/job/job-300003002339652?token=0~9d545f47-4919-4fe1-99c8-ce3c54a3426c&sectionRank=1&jobId=jobsdb-th-job-300003002339652
# Date Posted:  2021-03-31
#
#
# Company Name: Tongthai Information and Technology Co., Ltd.
# Position: Data Analyst  (เจ้าหน้าที่วิเคราะห์ข้อมูล)
# Location: Huaykwang
# Requirement not found
# Link:  https://th.jobsdb.com/th/en/job/job-300003002335991?token=0~9d545f47-4919-4fe1-99c8-ce3c54a3426c&sectionRank=2&jobId=jobsdb-th-job-300003002335991
# Date Posted:  2021-03-31
#
#
# Company Name: TD Tawandang Co., Ltd.
# Position: Data Scientist
# Location: Bangrak
# Requirement:
# •  Data Scientist
# ...
